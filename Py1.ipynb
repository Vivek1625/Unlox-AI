# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivek1625/Unlox-AI/blob/main/Py1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables & Datatypes

a = 9
print(a)
print(type(a))
# Out:
# 9
# <class 'int'>

# %% [markdown]
# String : Vivek, a, ""
# integers : 10, 0, ...
# Float : 0.01
#
# Boolean : true

# %%
#Lists

fruits = ["apple","banana","cherry", 1, 0.6]
print(fruits[0], fruits[2])
print(type(fruits))
print(type(fruits[4]))
print(fruits[0])
fruits[0] = "rose"
print(fruits[0])
#Elements in the lists can be changed after it is created
# Out:
# apple cherry
# <class 'list'>
# <class 'float'>
# apple
# rose

# %% [markdown]
# Slicing

# %%
#Dictionary {}
#Key : Value
user = {"name":"abc", "email":"abc.com"}

print(user)
print(type(user))
print(user["name"])
print(user["email"])
# Out:
# {'name': 'abc', 'email': 'abc.com'}
# <class 'dict'>
# abc
# abc.com

# %%
#create a tuple
coordinates = (1,2,6)
print(coordinates)
print(coordinates[0])
coordinates[0] = 50
print(coordinates[0])
#Elements in the tuple cannot be changed after it is created
# Out:
# (1, 2, 6)
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_156/833742024.py in <cell line: 0>()
#       3 print(coordinates)
#       4 print(coordinates[0])
# ----> 5 coordinates[0] = 50
#       6 print(coordinates[0])
#
# TypeError: 'tuple' object does not support item assignment
